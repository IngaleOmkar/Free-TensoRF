# %%
# !git clone https://github.com/IngaleOmkar/Free-TensoRF.git
# Out:
# Cloning into 'Free-TensoRF'...
# remote: Enumerating objects: 318, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 318 (delta 14), reused 22 (delta 8), pack-reused 287
# Receiving objects: 100% (318/318), 195.61 MiB | 25.10 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision
# !pip install tqdm scikit-image opencv-python configargparse lpips imageio-ffmpeg kornia lpips tensorboard
# !pip install jax
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 48.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 61.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 69.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 15.2 MB/s eta 0:00:00
# ...

# %%
# !pip install plyfile

# %% [markdown]
# This notebook corresponds to Free-TensoRF flower config with frequency regularisation (MLPRender_FRPE)

# %%
# !python Free-TensoRF/train.py --config Free-TensoRF/configs/flower.txt --basedir /content/Free-TensoRF/log/ --datadir "/content/drive/MyDrive/Colab Notebooks/nerf_llff_data/flower" --n_iters 10000 --freq 1 --shadingMode "MLP_PE"
# Out:
# 2024-03-24 01:01:32.932374: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-24 01:01:32.932486: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-24 01:01:33.042334: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-24 01:01:34.320576: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !zip -r /content/FRPE_10k_flower.zip /content/Free-TensoRF/log
# Out:
#   adding: content/Free-TensoRF/log/ (stored 0%)
#   adding: content/Free-TensoRF/log/.DS_Store (deflated 93%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/ (stored 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_rgba/ (stored 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/tensorf_flower_VM.th (deflated 9%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/events.out.tfevents.1711242120.b2f631ba5641.2033.0 (deflated 69%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/ (stored 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/010.png (deflated 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/014.png (deflated 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/023.png (deflated 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/091.png (deflated 0%)
# ...

# %%
# !cp /content/FRPE_10k_flower.zip /content/drive/MyDrive

# %%
# !cp /content/FRPE_10k_flower.csv /content/drive/MyDrive
