# %%
# !git clone https://github.com/IngaleOmkar/Free-TensoRF.git
# Out:
# Cloning into 'Free-TensoRF'...
# remote: Enumerating objects: 292, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 292 (delta 0), reused 3 (delta 0), pack-reused 287
# Receiving objects: 100% (292/292), 195.58 MiB | 34.37 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# !pip install torch torchvision
# !pip install tqdm scikit-image opencv-python configargparse lpips imageio-ffmpeg kornia lpips tensorboard
# !pip install jax
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 59.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 67.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 93.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.6 MB/s eta 0:00:00
# ...

# %%
# !pip install plyfile

# %%
# !python Free-TensoRF/train.py --config Free-TensoRF/configs/flower.txt --basedir /content/Free-TensoRF/log2/ --datadir "/content/drive/MyDrive/Colab Notebooks/nerf_llff_data/flower" --n_iters 10000 --freq 1 --shadingMode "MLP_PE"
# Out:
# 2024-03-19 21:43:35.721567: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-19 21:43:35.721614: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-19 21:43:35.723031: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-19 21:43:36.848128: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !python Free-TensoRF/train.py --config Free-TensoRF/configs/flower.txt --basedir /content/Free-TensoRF/log2/ --datadir "/content/drive/MyDrive/Colab Notebooks/nerf_llff_data/flower" --n_iters 10000
# Out:
# 2024-01-21 14:21:52.215903: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-21 14:21:52.215951: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-21 14:21:52.217295: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-21 14:21:53.311873: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !zip -r /content/trackerupdated.zip /content/Free-TensoRF/log2
# Out:
#   adding: content/Free-TensoRF/log/ (stored 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/ (stored 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/events.out.tfevents.1710877428.c45c0d906259.2832.0 (deflated 9%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/ (stored 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/041.png (deflated 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/024.png (deflated 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/114.png (deflated 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/056.png (deflated 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/033.png (deflated 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/065.png (deflated 0%)
#   adding: content/Free-TensoRF/log/tensorf_flower_VM/imgs_path_all/038.png (deflated 0%)
# ...

# %%
from google.colab import files
files.download("/content/trackerupdated.zip")

# %%
# !zip -r /content/og.zip /content/Free-TensoRF/log2
# Out:
#   adding: content/Free-TensoRF/log2/ (stored 0%)
#   adding: content/Free-TensoRF/log2/tensorf_flower_VM/ (stored 0%)
#   adding: content/Free-TensoRF/log2/tensorf_flower_VM/rgba/ (stored 0%)
#   adding: content/Free-TensoRF/log2/tensorf_flower_VM/imgs_path_all/ (stored 0%)
#   adding: content/Free-TensoRF/log2/tensorf_flower_VM/imgs_path_all/050.png (deflated 0%)
#   adding: content/Free-TensoRF/log2/tensorf_flower_VM/imgs_path_all/032.png (deflated 0%)
#   adding: content/Free-TensoRF/log2/tensorf_flower_VM/imgs_path_all/061.png (deflated 0%)
#   adding: content/Free-TensoRF/log2/tensorf_flower_VM/imgs_path_all/video.mp4 (deflated 0%)
#   adding: content/Free-TensoRF/log2/tensorf_flower_VM/imgs_path_all/094.png (deflated 0%)
#   adding: content/Free-TensoRF/log2/tensorf_flower_VM/imgs_path_all/111.png (deflated 0%)
#   adding: content/Free-TensoRF/log2/tensorf_flower_VM/imgs_path_all/086.png (deflated 0%)
# ...

# %%
files.download("/content/og.zip")
