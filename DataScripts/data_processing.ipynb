# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
pe_5k_flower = pd.read_csv('../PSNR_Data/PE_5k_flower.csv')
pe_10k_flower = pd.read_csv('../PSNR_Data/PE_10k_flower.csv')
frpe_10k_flower = pd.read_csv('../PSNR_Data/FRPE_10k_flower.csv')
frpe_5k_flower = pd.read_csv('../PSNR_Data/FRPE_5k_flower.csv')

fea_5k_flower = pd.read_csv('../PSNR_Data/FEA_5k_flower.csv')
fea_10k_flower = pd.read_csv('../PSNR_Data/FEA_10k_flower.csv')
frfea_10k_flower = pd.read_csv('../PSNR_Data/FRFEA_10k_flower.csv')
frfea_5k_flower = pd.read_csv('../PSNR_Data/FRFEA_5k_flower.csv')

# %%
# Plot the line graph for the PSNR values of the 5k iterations 
# The data only has one column of psnr values, ordered sequentially from 0 to 4999
# Label the x-axis as the iteration number and the y-axis as the PSNR value
# title the graph as "PSNR values of 5k iterations for the flower dataset"

plt.figure(figsize=(10,5))
plt.plot(pe_5k_flower)
plt.xlabel('Iteration Number')
plt.ylabel('PSNR Value')
plt.title('PSNR values of 5k iterations for the flower dataset (PE)')
plt.show()

# %%
# Plot the line graph for the PSNR values of the 10k iterations

plt.figure(figsize=(10,5))
plt.plot(pe_10k_flower)
plt.xlabel('Iteration Number')
plt.ylabel('PSNR Value')
plt.title('PSNR values of 10k iterations for the flower dataset (PE)')
plt.show()

# %%
# Plot the line graph for the PSNR values of the 10k iterations

plt.figure(figsize=(10,5))
plt.plot(frpe_10k_flower)
plt.xlabel('Iteration Number')
plt.ylabel('PSNR Value')
plt.title('PSNR values of 10k iterations for the flower dataset (FRPE)')
plt.show()

# %%
# Plot the line graph for the PSNR values of the 5k iterations frpe

plt.figure(figsize=(10,5))
plt.plot(pe_5k_flower)
plt.xlabel('Iteration Number')
plt.ylabel('PSNR Value')
plt.title('PSNR values of 5k iterations for the flower dataset (FRPE)')
plt.show()

# %%
# Now perform the same for the FEA data

plt.figure(figsize=(10,5))
plt.plot(fea_5k_flower)
plt.xlabel('Iteration Number')
plt.ylabel('PSNR Value')
plt.title('PSNR values of 5k iterations for the flower dataset (FEA)')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(fea_10k_flower)
plt.xlabel('Iteration Number')
plt.ylabel('PSNR Value')
plt.title('PSNR values of 10k iterations for the flower dataset (FEA)')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(frfea_10k_flower)
plt.xlabel('Iteration Number')
plt.ylabel('PSNR Value')
plt.title('PSNR values of 10k iterations for the flower dataset (FRFEA)')
plt.show()

# %%
# Plot the line graph for the PSNR values of the 5k iterations frpe

plt.figure(figsize=(10,5))
plt.plot(frfea_5k_flower)
plt.xlabel('Iteration Number')
plt.ylabel('PSNR Value')
plt.title('PSNR values of 5k iterations for the flower dataset (FRFEA)')
plt.show()

# %%
n_10k_psnr = {'PE': 27.771381304927843, 'FRPE': 28.002779190040492, 'FEA': 27.738211699456237, 'FRFEA': 27.79633682564155}
n_5k_psnr = {'PE': 26.751347360002597, 'FRPE': 26.83838927689309, 'FEA': 26.732835324965407, 'FRFEA': 26.715751321970526}

# %%
initial_method_vals = {'PE_5k': 26.751347360002597, 'PE_10k': 27.771381304927843, 'FEA_5k': 26.732835324965407, 'FEA_10k': 27.79633682564155}
improved_method_vals = {'FRPE_5k': 26.83838927689309, 'FRPE_10k': 28.002779190040492, 'FRFEA_5k': 26.715751321970526, 'FRFEA_10k': 27.79633682564155}

# %%
PE_vs_FRPE_5k = {'PE': 26.751347360002597, 'FRPE': 26.83838927689309}
PE_vs_FRPE_10k = {'PE': 27.771381304927843, 'FRPE': 28.002779190040492}
FEA_vs_FRFEA_5k = {'FEA': 26.732835324965407, 'FRFEA': 26.715751321970526}
FEA_vs_FRFEA_10k = {'FEA': 27.738211699456237, 'FRFEA': 27.79633682564155}

# %%
# Plot the bar graph for each of the 4 "vs" dictionaries

# PE vs FRPE for the 5k iterations

plt.figure(figsize=(6,5))
plt.bar(['Before', 'After'], PE_vs_FRPE_5k.values(), color='b')
plt.ylabel('PSNR Value')
plt.title('PSNR pre and post frequency regularisation (5k iterations)\nDecoder Function:MLP_PE')
plt.ylim(26.5, 26.9)
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.bar(['Before', 'After'], PE_vs_FRPE_10k.values(), color='b')
plt.ylabel('PSNR Value')
plt.title('PSNR pre and post frequency regularisation (10k iterations)\nDecoder Function:MLP_PE')
plt.ylim(27.5, 28.2)
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.bar(['Before', 'After'], FEA_vs_FRFEA_10k.values(), color='r')
plt.ylabel('PSNR Value')
plt.title('PSNR pre and post frequency regularisation (10k iterations)\nDecoder Function:MLP_FEA')
plt.ylim(27.5, 27.9)
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.bar(['Before', 'After'], FEA_vs_FRFEA_5k.values(), color='r')
plt.ylabel('PSNR Value')
plt.title('PSNR pre and post frequency regularisation (5k iterations)\nDecoder Function:MLP_FEA')
plt.ylim(26.5, 26.9)
plt.show()
