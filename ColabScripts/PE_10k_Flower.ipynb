# %%
# !git clone https://github.com/apchenstu/TensoRF.git
# Out:
# Cloning into 'TensoRF'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 117 (delta 53), reused 34 (delta 33), pack-reused 42
# Receiving objects: 100% (117/117), 51.65 KiB | 2.07 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision
# !pip install tqdm scikit-image opencv-python configargparse lpips imageio-ffmpeg kornia lpips tensorboard
# !pip install jax
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 37.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 51.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 39.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.2 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/nvidia-cusolver-cu12/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 3.3 MB/s eta 0:00:00
# ...

# %%
# !pip install plyfile

# %% [markdown]
# This notebook corresponds to Free-TensoRF flower config without frequency regularisation (10k)

# %%
# !python TensoRF/train.py --config TensoRF/configs/flower.txt --basedir /content/TensoRF/log/ --datadir "/content/drive/MyDrive/Colab Notebooks/nerf_llff_data/flower" --n_iters 10000
# Out:
# 2024-03-24 00:49:55.579295: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-24 00:49:55.579346: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-24 00:49:55.580715: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-24 00:49:56.758169: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !zip -r /content/PE_10k_flower.zip /content/TensoRF/log
# Out:
#   adding: content/TensoRF/log/ (stored 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/ (stored 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_rgba/ (stored 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/tensorf_flower_VM.th (deflated 9%)
#   adding: content/TensoRF/log/tensorf_flower_VM/events.out.tfevents.1711241334.56eb5d5ca624.3178.0 (deflated 9%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/ (stored 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/010.png (deflated 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/014.png (deflated 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/023.png (deflated 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/091.png (deflated 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/064.png (deflated 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/095.png (deflated 0%)
# ...

# %%
# !cp /content/PE_10k_flower.zip /content/drive/MyDrive

# %%
# !cp /content/PE_10k_flower.csv /content/drive/MyDrive
