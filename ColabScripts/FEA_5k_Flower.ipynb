# %%
# !git clone https://github.com/apchenstu/TensoRF.git
# Out:
# Cloning into 'TensoRF'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 117 (delta 53), reused 35 (delta 34), pack-reused 42
# Receiving objects: 100% (117/117), 51.65 KiB | 927.00 KiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision
# !pip install tqdm scikit-image opencv-python configargparse lpips imageio-ffmpeg kornia lpips tensorboard
# !pip install jax
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 59.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 71.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 92.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 17.1 MB/s eta 0:00:00
# ...

# %%
# !pip install plyfile

# %% [markdown]
# This notebook corresponds to Free-TensoRF flower config without frequency regularisation (10k)

# %%
# !python TensoRF/train.py --config TensoRF/configs/flower.txt --basedir /content/TensoRF/log/ --datadir "/content/drive/MyDrive/Colab Notebooks/nerf_llff_data/flower" --n_iters 5000 --shadingMode "MLP_Fea"
# Out:
# 2024-03-24 13:28:01.777964: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-24 13:28:01.778063: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-24 13:28:01.882914: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-24 13:28:03.241717: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !zip -r /content/FEA_5k_flower.zip /content/TensoRF/log
# Out:
#   adding: content/TensoRF/log/ (stored 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/ (stored 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_rgba/ (stored 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/events.out.tfevents.1711286932.2bf3fa3ecb50.1367.0 (deflated 69%)
#   adding: content/TensoRF/log/tensorf_flower_VM/tensorf_flower_VM.th (deflated 9%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/ (stored 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/010.png (deflated 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/014.png (deflated 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/023.png (deflated 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/091.png (deflated 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/064.png (deflated 0%)
#   adding: content/TensoRF/log/tensorf_flower_VM/imgs_path_all/095.png (deflated 0%)
# ...

# %%
# !cp /content/FEA_5k_flower.zip /content/drive/MyDrive

# %%
# !cp /content/FEA_5k_flower.csv /content/drive/MyDrive
